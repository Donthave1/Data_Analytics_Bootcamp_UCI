# %%
# Dependencie
import pandas as pd

# %%
# Load in file
marathon_2015 = "marathon_results_2015.csv"

# %%
marathon_2015_pd = pd.read_csv(marathon_2015)
marathon_2015_pd.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0           0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1           1   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2           2   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3           3  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4           4  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9   ...         25K      30K      35K      40K     Pace  \
# 0     NaN        NaN   ...     1:16:07  1:32:00  1:47:59  2:02:39  0:04:56
# 1     NaN        NaN   ...     1:16:07  1:31:59  1:47:59  2:02:42  0:04:58
# 2     NaN        NaN   ...     1:16:07  1:32:00  1:47:59  2:03:01  0:04:59
# 3     NaN        NaN   ...     1:16:07  1:32:00  1:48:03  2:03:47  0:05:00
# 4     NaN        NaN   ...     1:16:07  1:32:00  1:47:59  2:03:27  0:05:00
#
#   Proj Time Official Time Overall Gender Division
# ...

# %%
marathon_2015_pd.columns
# Out:
# Index(['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
#        'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
#        '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
#        'Gender', 'Division'],
#       dtype='object')

# %%
male_2015 = marathon_2015_pd.loc[marathon_2015_pd["M/F"] == "M", ['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
       'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
       '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
       'Gender', 'Division']]
male_2015.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0    Bib                         Name  Age M/F  \
# 0               0      3               Desisa, Lelisa   25   M
# 1               1      4        Tsegay, Yemane Adhane   30   M
# 2               2      8               Chebet, Wilson   29   M
# 3               3     11             Kipyego, Bernard   28   M
# 4               4     10                Korir, Wesley   32   M
# 5               5      9         Chepkwony, Frankline   30   M
# 6               6     14           Ritzenhein, Dathan   32   M
# 7               7      1              Keflezighi, Meb   39   M
# 8               8      5                 Tola, Tadese   27   M
# 9               9     16              Shafar, Vitaliy   33   M
# 10             10     22              Tegenkamp, Matt   33   M
# 11             11     19           Eggleston, Jeffrey   30   M
# 12             12     15               April, Lusapho   32   M
# ...

# %%
male_2015.to_csv("male_marathon_2015.csv", index=False)

# %%
female_2015 = marathon_2015_pd.loc[marathon_2015_pd["M/F"] == "F", ['Unnamed: 0', 'Bib', 'Name', 'Age', 'M/F', 'City', 'State', 'Country',
       'Citizen', 'Unnamed: 9', '5K', '10K', '15K', '20K', 'Half', '25K',
       '30K', '35K', '40K', 'Pace', 'Proj Time', 'Official Time', 'Overall',
       'Gender', 'Division']]
female_2015.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0    Bib                   Name  Age M/F             City  \
# 30             30    F11       Rotich, Caroline   30   F        Nyahururu
# 31             31     F2           Dibaba, Mare   25   F             Shoa
# 33             33     F1         Deba, Buzunesh   27   F             Arsi
# 39             39    F10        Linden, Desiree   31   F  Rochester Mills
# 43             43     F8         Cherop, Sharon   31   F         Marakwet
# 51             51     F9        Kilel, Caroline   34   F            Bomet
# 53             53     F3          Kebede, Aberu   28   F             Shoa
# 57             57     F6          Demise, Shure   19   F             Bore
# 61             61     F4      Flanagan, Shalane   33   F         Portland
# 74             74    F16       Chepkirui, Joyce   26   F             Iten
# 77             77     F5     Duliba, Aleksandra   27   F            Minsk
# ...

# %%
female_2015.to_csv("female_marathon_2015.csv", index=False)
