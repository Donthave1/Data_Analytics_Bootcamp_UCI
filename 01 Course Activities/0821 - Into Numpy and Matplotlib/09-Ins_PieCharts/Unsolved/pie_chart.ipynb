# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ["Humans", "Smurfs", "Hobbits", "Ninjas"]
sizes = [220, 95, 80, 100]
color = ["red", "orange", "lightcoral", "lightskyblue"]
explode_value = (0, 0, 0, 0)

# %%
plt.pie(sizes, explode=explode_value, labels=labels, colors=color, 
       autopct="%1.1f%%", shadow=True, startangle=140)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x1163ff240>,
#   <matplotlib.patches.Wedge at 0x1163ffba8>,
#   <matplotlib.patches.Wedge at 0x11640f668>,
#   <matplotlib.patches.Wedge at 0x116416128>],
#  [Text(-0.919253,-0.771345,'Humans'),
#   Text(0.993219,-0.472774,'Smurfs'),
#   Text(0.864658,0.679975,'Hobbits'),
#   Text(-0.259335,1.06899,'Ninjas')],
#  [Text(-0.536231,-0.449951,'44.4%'),
#   Text(0.541756,-0.257877,'19.2%'),
#   Text(0.471632,0.370895,'16.2%'),
#   Text(-0.141455,0.583087,'20.2%')])

# %%
plt.axis("equal")
# Out:
# (-1.1814062709521158,
#  1.1242339029468358,
#  -1.1955021571151263,
#  1.1277024356276102)
