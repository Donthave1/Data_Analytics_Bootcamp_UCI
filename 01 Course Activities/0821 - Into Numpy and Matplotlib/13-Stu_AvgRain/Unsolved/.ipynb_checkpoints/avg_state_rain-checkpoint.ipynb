# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
csv_path = "../Resources/avg_rain_state.csv"
rain_df = pd.read_csv(csv_path, encoding="utf-8")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20, 3))
plt.bar(x_axis, rain_df["Inches"], color = "r", alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1171ef8d0>,
#   <matplotlib.axis.XTick at 0x1171ef160>,
#   <matplotlib.axis.XTick at 0x1171e0a90>,
#   <matplotlib.axis.XTick at 0x118e21a58>,
#   <matplotlib.axis.XTick at 0x118e21f28>,
#   <matplotlib.axis.XTick at 0x118e2b438>,
#   <matplotlib.axis.XTick at 0x118e2b940>,
#   <matplotlib.axis.XTick at 0x118e2be48>,
#   <matplotlib.axis.XTick at 0x118e2b748>,
#   <matplotlib.axis.XTick at 0x118e21b38>,
#   <matplotlib.axis.XTick at 0x118e32710>,
#   <matplotlib.axis.XTick at 0x118e32c18>,
#   <matplotlib.axis.XTick at 0x118e3b198>,
#   <matplotlib.axis.XTick at 0x118e3b668>,
#   <matplotlib.axis.XTick at 0x118e3bb70>,
#   <matplotlib.axis.XTick at 0x118e43128>,
#   <matplotlib.axis.XTick at 0x118e435c0>,
#   <matplotlib.axis.XTick at 0x118e43ac8>,
#   <matplotlib.axis.XTick at 0x118e3b9e8>,
#   <matplotlib.axis.XTick at 0x118e21908>,
#   <matplotlib.axis.XTick at 0x118e43080>,
#   <matplotlib.axis.XTick at 0x118e4a358>,
#   <matplotlib.axis.XTick at 0x118e4a860>,
#   <matplotlib.axis.XTick at 0x118e4ad68>,
#   <matplotlib.axis.XTick at 0x118e522b0>,
#   <matplotlib.axis.XTick at 0x118e527b8>,
#   <matplotlib.axis.XTick at 0x118e52cc0>,
#   <matplotlib.axis.XTick at 0x118e52898>,
#   <matplotlib.axis.XTick at 0x118e4abe0>,
#   <matplotlib.axis.XTick at 0x118e325f8>,
#   <matplotlib.axis.XTick at 0x118e5c5c0>,
#   <matplotlib.axis.XTick at 0x118e5cac8>,
#   <matplotlib.axis.XTick at 0x118e5ccf8>,
#   <matplotlib.axis.XTick at 0x118e63518>,
#   <matplotlib.axis.XTick at 0x118e63a20>,
#   <matplotlib.axis.XTick at 0x118e63f28>,
#   <matplotlib.axis.XTick at 0x118e6b470>,
#   <matplotlib.axis.XTick at 0x118e63978>,
#   <matplotlib.axis.XTick at 0x118e5c470>,
#   <matplotlib.axis.XTick at 0x118e6b048>,
#   <matplotlib.axis.XTick at 0x118e6bcc0>,
#   <matplotlib.axis.XTick at 0x118e75208>,
#   <matplotlib.axis.XTick at 0x118e75710>,
#   <matplotlib.axis.XTick at 0x118e75c18>,
#   <matplotlib.axis.XTick at 0x118e7d198>,
#   <matplotlib.axis.XTick at 0x118e7d668>,
#   <matplotlib.axis.XTick at 0x118e75668>,
#   <matplotlib.axis.XTick at 0x118e6bb38>,
#   <matplotlib.axis.XTick at 0x118e7d828>,
#   <matplotlib.axis.XTick at 0x118e7df28>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0,0.5,'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain_test")
