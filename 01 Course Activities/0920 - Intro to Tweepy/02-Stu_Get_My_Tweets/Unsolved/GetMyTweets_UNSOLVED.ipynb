# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Import Twitter API Keys
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Get all tweets from home feed
public_tweets = api.user_timeline()

# %%
# Loop through all tweets and print a prettified JSON of each tweet
for tweet in public_tweets:
    print(json.dumps(tweet, sort_keys=True, indent=4))
# Out:
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Thu Sep 20 00:37:57 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "gcppodcast.com/post/episode-1\u2026",
#                 "expanded_url": "https://www.gcppodcast.com/post/episode-146-google-ai-with-jeff-dean/",
#                 "indices": [
#                     28,
#                     51
#                 ],
#                 "url": "https://t.co/3DPDvuSThY"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 3401912177,
#                 "id_str": "3401912177",
#                 "indices": [
#                     56,
#                     67
#                 ],
#                 "name": "GCP Podcast",
#                 "screen_name": "GCPPodcast"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1042573542833893376,
#     "id_str": "1042573542833893376",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "\"Google AI with Jeff Dean\"\n https://t.co/3DPDvuSThY via @gcppodcast",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Aug 23 02:09:27 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 1,
#         "following": false,
#         "friends_count": 49,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1032449709137309696,
#         "id_str": "1032449709137309696",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Edward Chen",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "EdwardC16414025",
#         "statuses_count": 3,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Sep 11 04:07:46 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "medium.mybridge.co/30-amazing-mac\u2026",
#                 "expanded_url": "https://medium.mybridge.co/30-amazing-machine-learning-projects-for-the-past-year-v-2018-b853b8621ac7",
#                 "indices": [
#                     79,
#                     102
#                 ],
#                 "url": "https://t.co/9O1b9zzC5M"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 2596989619,
#                 "id_str": "2596989619",
#                 "indices": [
#                     69,
#                     78
#                 ],
#                 "name": "Mybridge",
#                 "screen_name": "Mybridge"
#             }
#         ]
#     },
#     "favorite_count": 2,
#     "favorited": false,
#     "geo": null,
#     "id": 1039364856732762112,
#     "id_str": "1039364856732762112",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "\u201c30 Amazing Machine Learning Projects for the Past Year (v.2018)\u201d by @Mybridge https://t.co/9O1b9zzC5M",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Aug 23 02:09:27 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 1,
#         "following": false,
#         "friends_count": 49,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1032449709137309696,
#         "id_str": "1032449709137309696",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Edward Chen",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "EdwardC16414025",
#         "statuses_count": 3,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
# {
#     "contributors": null,
#     "coordinates": null,
#     "created_at": "Tue Sep 11 03:44:05 +0000 2018",
#     "entities": {
#         "hashtags": [],
#         "symbols": [],
#         "urls": [
#             {
#                 "display_url": "medium.com/google-design/\u2026",
#                 "expanded_url": "https://medium.com/google-design/designing-the-future-of-work-c84e9b3e63",
#                 "indices": [
#                     44,
#                     67
#                 ],
#                 "url": "https://t.co/wc5K1ufu52"
#             }
#         ],
#         "user_mentions": [
#             {
#                 "id": 360963964,
#                 "id_str": "360963964",
#                 "indices": [
#                     34,
#                     43
#                 ],
#                 "name": "Sara Ortloff Khoury",
#                 "screen_name": "sokhoury"
#             }
#         ]
#     },
#     "favorite_count": 0,
#     "favorited": false,
#     "geo": null,
#     "id": 1039358893535649792,
#     "id_str": "1039358893535649792",
#     "in_reply_to_screen_name": null,
#     "in_reply_to_status_id": null,
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_user_id": null,
#     "in_reply_to_user_id_str": null,
#     "is_quote_status": false,
#     "lang": "en",
#     "place": null,
#     "possibly_sensitive": false,
#     "retweet_count": 0,
#     "retweeted": false,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "text": "\u201cDesigning the Future of Work\u201d by @sokhoury https://t.co/wc5K1ufu52",
#     "truncated": false,
#     "user": {
#         "contributors_enabled": false,
#         "created_at": "Thu Aug 23 02:09:27 +0000 2018",
#         "default_profile": true,
#         "default_profile_image": true,
#         "description": "",
#         "entities": {
#             "description": {
#                 "urls": []
#             }
#         },
#         "favourites_count": 0,
#         "follow_request_sent": false,
#         "followers_count": 1,
#         "following": false,
#         "friends_count": 49,
#         "geo_enabled": false,
#         "has_extended_profile": false,
#         "id": 1032449709137309696,
#         "id_str": "1032449709137309696",
#         "is_translation_enabled": false,
#         "is_translator": false,
#         "lang": "en",
#         "listed_count": 0,
#         "location": "",
#         "name": "Edward Chen",
#         "notifications": false,
#         "profile_background_color": "F5F8FA",
#         "profile_background_image_url": null,
#         "profile_background_image_url_https": null,
#         "profile_background_tile": false,
#         "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png",
#         "profile_link_color": "1DA1F2",
#         "profile_sidebar_border_color": "C0DEED",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "profile_use_background_image": true,
#         "protected": false,
#         "screen_name": "EdwardC16414025",
#         "statuses_count": 3,
#         "time_zone": null,
#         "translator_type": "none",
#         "url": null,
#         "utc_offset": null,
#         "verified": false
#     }
# }
