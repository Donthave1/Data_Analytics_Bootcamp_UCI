# %%
# Dependencies
import tweepy
import json
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
search_term = input("Which term would you like to search for? ")
public_tweets = api.search(search_term)
public_tweets
# Out:
# Which term would you like to search for? dogs
# {'statuses': [{'created_at': 'Fri Sep 21 03:59:16 +0000 2018',
#    'id': 1042986593626148864,
#    'id_str': '1042986593626148864',
#    'text': 'What I see when I look up from my phone. #puppyfeet #dogs #dogsofinstagram #minpinstagram #rescuedog #adoptdontshop https://t.co/oYp65JnSU7',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'puppyfeet', 'indices': [41, 51]},
#      {'text': 'dogs', 'indices': [52, 57]},
#      {'text': 'dogsofinstagram', 'indices': [58, 74]},
#      {'text': 'minpinstagram', 'indices': [75, 89]},
#      {'text': 'rescuedog', 'indices': [90, 100]},
#      {'text': 'adoptdontshop', 'indices': [101, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/oYp65JnSU7',
#       'expanded_url': 'https://www.instagram.com/p/Bn-VP4DA9-B/?utm_source=ig_twitter_share&igshid=1u3ivnuq1g5wa',
#       'display_url': 'instagram.com/p/Bn-VP4DA9-B/…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25345510,
#     'id_str': '25345510',
#     'name': 'Alyssapalooza #BeAMisha',
#     'screen_name': 'RushChick2112',
#     'location': 'Cedar Creek, Tx',
#     'description': 'Fur mom to Lynkoln & Lundy. Ginger Unicorn Princess. Mental Health Warrior. Rush fan.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 54,
#     'friends_count': 315,
#     'listed_count': 1,
#     'created_at': 'Thu Mar 19 17:37:34 +0000 2009',
#     'favourites_count': 4190,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 1084,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '841515',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1001278936989528064/SiKqb707_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1001278936989528064/SiKqb707_normal.jpg',
#     'profile_link_color': '08820C',
#     'profile_sidebar_border_color': '157E0C',
#     'profile_sidebar_fill_color': '9AF38C',
#     'profile_text_color': '0D9B14',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:15 +0000 2018',
#    'id': 1042986589461262336,
#    'id_str': '1042986589461262336',
#    'text': 'RT @carbon_180: Our #MondayMotivation? Dreaming up new ways for science nerds, policy wonks &amp; business leaders to address climate change to…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MondayMotivation',
#       'indices': [20, 37]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'carbon_180',
#       'name': 'Carbon180',
#       'id': 3164575344,
#       'id_str': '3164575344',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1003378853585141760,
#     'id_str': '1003378853585141760',
#     'name': 'Jeanette Amador',
#     'screen_name': 'JeanetteAmador3',
#     'location': 'California, USA',
#     'description': 'Learner/educator meeting each challenge with passion, compassion and humor.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7,
#     'friends_count': 49,
#     'listed_count': 0,
#     'created_at': 'Sun Jun 03 20:52:15 +0000 2018',
#     'favourites_count': 16,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 9,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1003397006289702918/ZKmT2Rmo_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1003397006289702918/ZKmT2Rmo_normal.jpg',
#     'profile_link_color': '91D2FA',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Oct 17 00:12:26 +0000 2017',
#     'id': 920080023771430912,
#     'id_str': '920080023771430912',
#     'text': 'Our #MondayMotivation? Dreaming up new ways for science nerds, policy wonks &amp; business leaders to address climate c… https://t.co/XmywFrmZVG',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MondayMotivation',
#        'indices': [4, 21]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/XmywFrmZVG',
#        'expanded_url': 'https://twitter.com/i/web/status/920080023771430912',
#        'display_url': 'twitter.com/i/web/status/9…',
#        'indices': [121, 144]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 3164575344,
#      'id_str': '3164575344',
#      'name': 'Carbon180',
#      'screen_name': 'carbon_180',
#      'location': 'Oakland, CA',
#      'description': 'Carbon180 is a new breed of climate-focused NGO on a mission to fundamentally rethink carbon. Formerly Center for Carbon Removal.',
#      'url': 'https://t.co/bE7YMqrpTV',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/bE7YMqrpTV',
#          'expanded_url': 'http://carbon180.org',
#          'display_url': 'carbon180.org',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 1914,
#      'friends_count': 439,
#      'listed_count': 81,
#      'created_at': 'Mon Apr 20 01:29:22 +0000 2015',
#      'favourites_count': 615,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1729,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1039729819594969088/DvDHI4Oq_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1039729819594969088/DvDHI4Oq_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3164575344/1536726452',
#      'profile_link_color': '9EC76E',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 8,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:15 +0000 2018',
#    'id': 1042986588311965702,
#    'id_str': '1042986588311965702',
#    'text': "RT @jojoh888: Here's my non-political tweet for tonight, enjoy #dogsarelove #doglover #dogs 😍❤🐶❤🐾🐾\n\n#JJNonPoliticalTweet https://t.co/AhAUW…",
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'dogsarelove', 'indices': [63, 75]},
#      {'text': 'doglover', 'indices': [76, 85]},
#      {'text': 'dogs', 'indices': [86, 91]},
#      {'text': 'JJNonPoliticalTweet', 'indices': [100, 120]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jojoh888',
#       'name': '🇺🇸Jojoh888🇺🇸',
#       'id': 2369640619,
#       'id_str': '2369640619',
#       'indices': [3, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 4718357002,
#     'id_str': '4718357002',
#     'name': 'Susan Mcginley',
#     'screen_name': 'obannons1969111',
#     'location': 'St Martin, MS',
#     'description': 'Wife, Christian, Trump Lover, retired casino , Mom, Grandmom, #MAGA "#ThankyouTrump" # WALK AWAY!!!  NO DM’S',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6455,
#     'friends_count': 5633,
#     'listed_count': 139,
#     'created_at': 'Tue Jan 05 21:07:19 +0000 2016',
#     'favourites_count': 141979,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 152421,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/863626395657830400/r5TK3dWZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/863626395657830400/r5TK3dWZ_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Sep 21 03:02:02 +0000 2018',
#     'id': 1042972190633865216,
#     'id_str': '1042972190633865216',
#     'text': "Here's my non-political tweet for tonight, enjoy #dogsarelove #doglover #dogs 😍❤🐶❤🐾🐾\n\n#JJNonPoliticalTweet https://t.co/AhAUWtcIXX",
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'dogsarelove', 'indices': [49, 61]},
#       {'text': 'doglover', 'indices': [62, 71]},
#       {'text': 'dogs', 'indices': [72, 77]},
#       {'text': 'JJNonPoliticalTweet', 'indices': [86, 106]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1042971287209922561,
#        'id_str': '1042971287209922561',
#        'indices': [107, 130],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1042971287209922561/pu/img/Z1BiehmbjceOxusU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1042971287209922561/pu/img/Z1BiehmbjceOxusU.jpg',
#        'url': 'https://t.co/AhAUWtcIXX',
#        'display_url': 'pic.twitter.com/AhAUWtcIXX',
#        'expanded_url': 'https://twitter.com/jojoh888/status/1042972190633865216/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1042971287209922561,
#        'id_str': '1042971287209922561',
#        'indices': [107, 130],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1042971287209922561/pu/img/Z1BiehmbjceOxusU.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1042971287209922561/pu/img/Z1BiehmbjceOxusU.jpg',
#        'url': 'https://t.co/AhAUWtcIXX',
#        'display_url': 'pic.twitter.com/AhAUWtcIXX',
#        'expanded_url': 'https://twitter.com/jojoh888/status/1042972190633865216/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#         'medium': {'w': 720, 'h': 720, 'resize': 'fit'},
#         'large': {'w': 720, 'h': 720, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [1, 1],
#         'duration_millis': 48984,
#         'variants': [{'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1042971287209922561/pu/vid/480x480/oaypWM5S82vbOCzi.mp4?tag=5'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1042971287209922561/pu/pl/uNEpKltpmC9Y4_4j.m3u8?tag=5'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1042971287209922561/pu/vid/240x240/Pr1O1xXl47UXWQsP.mp4?tag=5'},
#          {'bitrate': 1280000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1042971287209922561/pu/vid/720x720/OBIyFSDftEaylGsq.mp4?tag=5'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 2369640619,
#      'id_str': '2369640619',
#      'name': '🇺🇸Jojoh888🇺🇸',
#      'screen_name': 'jojoh888',
#      'location': ' MAGA #JJNonPoliticalTweet ',
#      'description': 'This is my only account. #AmericaFirst #PresidentTrump #BuildTheWall #2A FB @DineshDSouza @seanhannity @ScottBaio @StephenBaldwin7 @antoniosabatojr Doery2',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 86816,
#      'friends_count': 2744,
#      'listed_count': 241,
#      'created_at': 'Mon Mar 03 01:32:34 +0000 2014',
#      'favourites_count': 59577,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 76503,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/826253037308100610/A83up3Cx_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/826253037308100610/A83up3Cx_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2369640619/1516588519',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 85,
#     'favorite_count': 156,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 85,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:14 +0000 2018',
#    'id': 1042986584570642432,
#    'id_str': '1042986584570642432',
#    'text': 'RT @Hocchama: 【保健所収容】里親募集 里親様を待っています。子犬♂黒茶 掲載期限2018年0 9月21日まで 山口健康福祉センター 防府支所 食品衛生課 山口県防府市駅南町13-40 防府合同庁舎1F https://t.co/aGiqWdQ2kI',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Hocchama',
#       'name': 'Hocchi\uf8ff',
#       'id': 147835232,
#       'id_str': '147835232',
#       'indices': [3, 12]}],
#     'urls': [{'url': 'https://t.co/aGiqWdQ2kI',
#       'expanded_url': 'https://www.pet-home.jp/dogs/yamaguchi/pn228819/',
#       'display_url': 'pet-home.jp/dogs/yamaguchi…',
#       'indices': [108, 131]}]},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 995671351514951680,
#     'id_str': '995671351514951680',
#     'name': 'ひでさん',
#     'screen_name': 'HY36264327',
#     'location': '奈良 橿原市',
#     'description': '保護ネコちゃんを迎える条件作り中です。それと動物愛護活動をされている方の後方支援で、少しでもお役に立てればと思いTwitterを始めました。今は定期的に譲渡会に行き啓発の写真を投稿しています。',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 124,
#     'friends_count': 132,
#     'listed_count': 0,
#     'created_at': 'Sun May 13 14:25:23 +0000 2018',
#     'favourites_count': 4,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 7400,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1010575138293624832/NKXl1QdR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1010575138293624832/NKXl1QdR_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 20 14:01:22 +0000 2018',
#     'id': 1042775727970508802,
#     'id_str': '1042775727970508802',
#     'text': '【保健所収容】里親募集 里親様を待っています。子犬♂黒茶 掲載期限2018年0 9月21日まで 山口健康福祉センター 防府支所 食品衛生課 山口県防府市駅南町13-40 防府合同庁舎1F https://t.co/aGiqWdQ2kI',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/aGiqWdQ2kI',
#        'expanded_url': 'https://www.pet-home.jp/dogs/yamaguchi/pn228819/',
#        'display_url': 'pet-home.jp/dogs/yamaguchi…',
#        'indices': [94, 117]}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 147835232,
#      'id_str': '147835232',
#      'name': 'Hocchi\uf8ff',
#      'screen_name': 'Hocchama',
#      'location': '三次元なう。',
#      'description': '友達の友達は皆友達だ。 世界に広げよう友達の”和”！',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 387,
#      'friends_count': 32,
#      'listed_count': 9,
#      'created_at': 'Tue May 25 04:58:01 +0000 2010',
#      'favourites_count': 13,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 16532,
#      'lang': 'ja',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'FFF04D',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/815170254846296065/dFw_lnF0_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/815170254846296065/dFw_lnF0_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/147835232/1370878681',
#      'profile_link_color': '0099CC',
#      'profile_sidebar_border_color': 'FFF8AD',
#      'profile_sidebar_fill_color': 'F6FFD1',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 15,
#     'favorite_count': 4,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 15,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Fri Sep 21 03:59:12 +0000 2018',
#    'id': 1042986576744083457,
#    'id_str': '1042986576744083457',
#    'text': 'RT @VIEWSFROMJAY23: Dogs: *Can sniff out cancer*\n\nMe: “Dogs are so smart.”\n\nAlso dogs: https://t.co/9HaxzeSpEJ',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'VIEWSFROMJAY23',
#       'name': 'TrapMoneyJay 💎',
#       'id': 970132091202691073,
#       'id_str': '970132091202691073',
#       'indices': [3, 18]}],
#     'urls': [],
#     'media': [{'id': 1041922256740524032,
#       'id_str': '1041922256740524032',
#       'indices': [87, 110],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#       'url': 'https://t.co/9HaxzeSpEJ',
#       'display_url': 'pic.twitter.com/9HaxzeSpEJ',
#       'expanded_url': 'https://twitter.com/VIEWSFROMJAY23/status/1041922307315433472/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 512, 'h': 640, 'resize': 'fit'},
#        'small': {'w': 512, 'h': 640, 'resize': 'fit'},
#        'medium': {'w': 512, 'h': 640, 'resize': 'fit'}},
#       'source_status_id': 1041922307315433472,
#       'source_status_id_str': '1041922307315433472',
#       'source_user_id': 970132091202691073,
#       'source_user_id_str': '970132091202691073'}]},
#    'extended_entities': {'media': [{'id': 1041922256740524032,
#       'id_str': '1041922256740524032',
#       'indices': [87, 110],
#       'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#       'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#       'url': 'https://t.co/9HaxzeSpEJ',
#       'display_url': 'pic.twitter.com/9HaxzeSpEJ',
#       'expanded_url': 'https://twitter.com/VIEWSFROMJAY23/status/1041922307315433472/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 512, 'h': 640, 'resize': 'fit'},
#        'small': {'w': 512, 'h': 640, 'resize': 'fit'},
#        'medium': {'w': 512, 'h': 640, 'resize': 'fit'}},
#       'source_status_id': 1041922307315433472,
#       'source_status_id_str': '1041922307315433472',
#       'source_user_id': 970132091202691073,
#       'source_user_id_str': '970132091202691073',
#       'video_info': {'aspect_ratio': [4, 5],
#        'duration_millis': 19767,
#        'variants': [{'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/vid/360x450/JRcKp3YmkSHvC93O.mp4?tag=5'},
#         {'bitrate': 256000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/vid/180x224/a_dCtLaXjK4m9IVU.mp4?tag=5'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/vid/512x640/sSXzFb49tpL9xSV9.mp4?tag=5'},
#         {'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/pl/mp1lmr0oFw05elOW.m3u8?tag=5'}]},
#       'additional_media_info': {'monetizable': False,
#        'source_user': {'id': 970132091202691073,
#         'id_str': '970132091202691073',
#         'name': 'TrapMoneyJay 💎',
#         'screen_name': 'VIEWSFROMJAY23',
#         'location': 'Suspended at 20k',
#         'description': '“Can’t go 50-50 with no hoe”// 👻Viewsfromjay23',
#         'url': 'https://t.co/psvAGqrukE',
#         'entities': {'url': {'urls': [{'url': 'https://t.co/psvAGqrukE',
#             'expanded_url': 'http://Cash.me/$Viewsfromjay23',
#             'display_url': 'Cash.me/$Viewsfromjay23',
#             'indices': [0, 23]}]},
#          'description': {'urls': []}},
#         'protected': False,
#         'followers_count': 5219,
#         'friends_count': 4691,
#         'listed_count': 66,
#         'created_at': 'Sun Mar 04 03:01:29 +0000 2018',
#         'favourites_count': 811,
#         'utc_offset': None,
#         'time_zone': None,
#         'geo_enabled': False,
#         'verified': False,
#         'statuses_count': 1212,
#         'lang': 'en',
#         'contributors_enabled': False,
#         'is_translator': False,
#         'is_translation_enabled': False,
#         'profile_background_color': 'F5F8FA',
#         'profile_background_image_url': None,
#         'profile_background_image_url_https': None,
#         'profile_background_tile': False,
#         'profile_image_url': 'http://pbs.twimg.com/profile_images/1022615985801633797/BSCKcKNj_normal.jpg',
#         'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1022615985801633797/BSCKcKNj_normal.jpg',
#         'profile_banner_url': 'https://pbs.twimg.com/profile_banners/970132091202691073/1536044538',
#         'profile_link_color': '1DA1F2',
#         'profile_sidebar_border_color': 'C0DEED',
#         'profile_sidebar_fill_color': 'DDEEF6',
#         'profile_text_color': '333333',
#         'profile_use_background_image': True,
#         'has_extended_profile': True,
#         'default_profile': True,
#         'default_profile_image': False,
#         'following': False,
#         'follow_request_sent': False,
#         'notifications': False,
#         'translator_type': 'none'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 451800041,
#     'id_str': '451800041',
#     'name': 'Jaime K',
#     'screen_name': 'SavetheKales',
#     'location': 'Easton, PA',
#     'description': '✨Feelings and eyeliner✨ Host of Save the Kales! vegan TV show. Writer & encourager. Books, queers, kindness. Easton, PA.',
#     'url': 'https://t.co/s8yxaNcU56',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/s8yxaNcU56',
#         'expanded_url': 'http://www.SavetheKales.com',
#         'display_url': 'SavetheKales.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1762,
#     'friends_count': 1068,
#     'listed_count': 70,
#     'created_at': 'Sun Jan 01 01:35:35 +0000 2012',
#     'favourites_count': 4615,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 12918,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F2F5',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1024464077605744640/OvLVAGUZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1024464077605744640/OvLVAGUZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/451800041/1418215580',
#     'profile_link_color': '515052',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Tue Sep 18 05:30:10 +0000 2018',
#     'id': 1041922307315433472,
#     'id_str': '1041922307315433472',
#     'text': 'Dogs: *Can sniff out cancer*\n\nMe: “Dogs are so smart.”\n\nAlso dogs: https://t.co/9HaxzeSpEJ',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1041922256740524032,
#        'id_str': '1041922256740524032',
#        'indices': [67, 90],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#        'url': 'https://t.co/9HaxzeSpEJ',
#        'display_url': 'pic.twitter.com/9HaxzeSpEJ',
#        'expanded_url': 'https://twitter.com/VIEWSFROMJAY23/status/1041922307315433472/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 512, 'h': 640, 'resize': 'fit'},
#         'small': {'w': 512, 'h': 640, 'resize': 'fit'},
#         'medium': {'w': 512, 'h': 640, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1041922256740524032,
#        'id_str': '1041922256740524032',
#        'indices': [67, 90],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1041922256740524032/pu/img/FNP4kksB3YM77df7.jpg',
#        'url': 'https://t.co/9HaxzeSpEJ',
#        'display_url': 'pic.twitter.com/9HaxzeSpEJ',
#        'expanded_url': 'https://twitter.com/VIEWSFROMJAY23/status/1041922307315433472/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'large': {'w': 512, 'h': 640, 'resize': 'fit'},
#         'small': {'w': 512, 'h': 640, 'resize': 'fit'},
#         'medium': {'w': 512, 'h': 640, 'resize': 'fit'}},
#        'video_info': {'aspect_ratio': [4, 5],
#         'duration_millis': 19767,
#         'variants': [{'bitrate': 832000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/vid/360x450/JRcKp3YmkSHvC93O.mp4?tag=5'},
#          {'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/vid/180x224/a_dCtLaXjK4m9IVU.mp4?tag=5'},
#          {'bitrate': 2176000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/vid/512x640/sSXzFb49tpL9xSV9.mp4?tag=5'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/1041922256740524032/pu/pl/mp1lmr0oFw05elOW.m3u8?tag=5'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 970132091202691073,
#      'id_str': '970132091202691073',
#      'name': 'TrapMoneyJay 💎',
#      'screen_name': 'VIEWSFROMJAY23',
#      'location': 'Suspended at 20k',
#      'description': '“Can’t go 50-50 with no hoe”// 👻Viewsfromjay23',
#      'url': 'https://t.co/psvAGqrukE',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/psvAGqrukE',
#          'expanded_url': 'http://Cash.me/$Viewsfromjay23',
#          'display_url': 'Cash.me/$Viewsfromjay23',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 5219,
#      'friends_count': 4691,
#      'listed_count': 66,
#      'created_at': 'Sun Mar 04 03:01:29 +0000 2018',
#      'favourites_count': 811,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 1212,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1022615985801633797/BSCKcKNj_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1022615985801633797/BSCKcKNj_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/970132091202691073/1536044538',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 70251,
#     'favorite_count': 248888,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': True,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 70251,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:11 +0000 2018',
#    'id': 1042986573648691201,
#    'id_str': '1042986573648691201',
#    'text': "RT @CBSNews: ALL THE FEELS: An abandoned dog anxiously paces across a porch surrounded by Florence's floodwaters, when someone finally arri…",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CBSNews',
#       'name': 'CBS News',
#       'id': 15012486,
#       'id_str': '15012486',
#       'indices': [3, 11]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 111981108,
#     'id_str': '111981108',
#     'name': 'Ahmad',
#     'screen_name': 'BigARashad',
#     'location': '',
#     'description': 'Chi Alpha Leader, passionate Steelers fan and college graduate!!! I also live tweet Steelers games, the best live tweets anywhere!!! #GodFirst #StairwaytoSeven',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3529,
#     'friends_count': 2735,
#     'listed_count': 92,
#     'created_at': 'Sat Feb 06 20:59:37 +0000 2010',
#     'favourites_count': 26420,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 120559,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1196428989/Troy-Polamalu-5_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1196428989/Troy-Polamalu-5_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/111981108/1450809522',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Wed Sep 19 18:05:07 +0000 2018',
#     'id': 1042474682849656832,
#     'id_str': '1042474682849656832',
#     'text': "ALL THE FEELS: An abandoned dog anxiously paces across a porch surrounded by Florence's floodwaters, when someone f… https://t.co/fSjtwAov4L",
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/fSjtwAov4L',
#        'expanded_url': 'https://twitter.com/i/web/status/1042474682849656832',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://www.sprinklr.com" rel="nofollow">Sprinklr</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 15012486,
#      'id_str': '15012486',
#      'name': 'CBS News',
#      'screen_name': 'CBSNews',
#      'location': 'New York, NY',
#      'description': 'Your source for original reporting and trusted news.',
#      'url': 'https://t.co/VGut7r2Vg5',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/VGut7r2Vg5',
#          'expanded_url': 'http://CBSNews.com',
#          'display_url': 'CBSNews.com',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 6441740,
#      'friends_count': 436,
#      'listed_count': 48768,
#      'created_at': 'Thu Jun 05 00:54:31 +0000 2008',
#      'favourites_count': 272,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': True,
#      'statuses_count': 189115,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': True,
#      'profile_background_color': 'D9DADA',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/645966750941626368/d0Q4voGK_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15012486/1527023725',
#      'profile_link_color': 'B12124',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'EAEDF0',
#      'profile_text_color': '000000',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 6102,
#     'favorite_count': 23423,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 6102,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:11 +0000 2018',
#    'id': 1042986572432297984,
#    'id_str': '1042986572432297984',
#    'text': "To be clear, Tunechi is MISSING however there's dogs, cats and falcons in the area that WILL EAT tunechi on sight.… https://t.co/0eSvT6myLq",
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/0eSvT6myLq',
#       'expanded_url': 'https://twitter.com/i/web/status/1042986572432297984',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1117673498,
#     'id_str': '1117673498',
#     'name': 'Coyote',
#     'screen_name': 'ComicXans',
#     'location': '',
#     'description': 'As Wild as the West Texas Winds',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 180,
#     'friends_count': 233,
#     'listed_count': 13,
#     'created_at': 'Thu Jan 24 20:24:38 +0000 2013',
#     'favourites_count': 8802,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 18111,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1039023405050290176/SNoJOlID_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1039023405050290176/SNoJOlID_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1117673498/1534307216',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:10 +0000 2018',
#    'id': 1042986571195006977,
#    'id_str': '1042986571195006977',
#    'text': 'RT @DonaldJTrumpJr: Ironically, there are few orgs in world history that have as much animal blood on their hands as PETA. You hypocrites a…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'DonaldJTrumpJr',
#       'name': 'Donald Trump Jr.',
#       'id': 39344374,
#       'id_str': '39344374',
#       'indices': [3, 18]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 958339681879441409,
#     'id_str': '958339681879441409',
#     'name': 'akaadreg❌liberal❌lies❌',
#     'screen_name': 'jesussaves12341',
#     'location': 'Santa Cruz, CA',
#     'description': 'I’m only on Twitter to support my President! #TrumpRocks 💥Jesus isn’t surprised by any of this so don’t worry be 😃 happy',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 354,
#     'friends_count': 630,
#     'listed_count': 10,
#     'created_at': 'Tue Jan 30 14:02:40 +0000 2018',
#     'favourites_count': 18643,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 20555,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1042607366015873024/mLux6McU_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1042607366015873024/mLux6McU_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/958339681879441409/1536294958',
# ...
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:06 +0000 2018',
#    'id': 1042986553511837696,
#    'id_str': '1042986553511837696',
#    'text': 'RT @y3HYQRp2Rm2Qzlr: 里親様が決まりました❣️里親様、ボランティア様、ありがとうございました🙇😭\n他にも新しい家族を待っている子は全国にたくさんいます。\nペットショップでお金で命を買うのではなく、保健所に収容されている子の里親になる選択肢をお願い致します。…',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'y3HYQRp2Rm2Qzlr',
#       'name': 'なるは',
#       'id': 863217614868234241,
#       'id_str': '863217614868234241',
#       'indices': [3, 19]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2995435130,
#     'id_str': '2995435130',
#     'name': 'rokomaru#END殺処分JAPAN',
#     'screen_name': 'twins0131',
#     'location': '',
#     'description': 'ペットショップの裏で繁殖犬(猫)が産む機械にされた挙げ句殺されています！生体販売反対!あなたの愛犬(猫)の親がどんな姿か知っていますか？ペット流通の闇を知って拡めて下さい!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1960,
#     'friends_count': 1092,
#     'listed_count': 62,
#     'created_at': 'Sun Jan 25 05:33:48 +0000 2015',
#     'favourites_count': 1253,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 315743,
#     'lang': 'ja',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/860135534957481984/3vK9QVEc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/860135534957481984/3vK9QVEc_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2995435130/1424005818',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Thu Sep 20 11:02:12 +0000 2018',
#     'id': 1042730641240993792,
#     'id_str': '1042730641240993792',
#     'text': '里親様が決まりました❣️里親様、ボランティア様、ありがとうございました🙇😭\n他にも新しい家族を待っている子は全国にたくさんいます。\nペットショップでお金で命を買うのではなく、保健所に収容されている子の里親になる選択肢をお願い致しま… https://t.co/Ka7dKMMSis',
#     'truncated': True,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/Ka7dKMMSis',
#        'expanded_url': 'https://twitter.com/i/web/status/1042730641240993792',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'ja', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 863217614868234241,
#      'id_str': '863217614868234241',
#      'name': 'なるは',
#      'screen_name': 'y3HYQRp2Rm2Qzlr',
#      'location': '愛知県',
#      'description': '動物が大好きです。愛犬を１匹飼っています。動物虐待、多頭飼育崩壊、毛皮、動物実験、動物殺処分断固反対。自分にできることを見つけて少しでも貢献したいと思います。ゆくゆくは、保護預り等出来るようになりたいと考えています。情報拡散、支援物資、寄付等活動しています。Instagramにて、画像掲載しております。',
#      'url': 'https://t.co/9Ixs1Wj0JD',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/9Ixs1Wj0JD',
#          'expanded_url': 'http://Instagram.com/save.dogs.cats.japan',
#          'display_url': 'Instagram.com/save.dogs.cats…',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 2119,
#      'friends_count': 1583,
#      'listed_count': 9,
#      'created_at': 'Sat May 13 02:21:32 +0000 2017',
#      'favourites_count': 6023,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': False,
#      'verified': False,
#      'statuses_count': 29190,
#      'lang': 'ja',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/865332410665230336/mLQC1D4E_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/865332410665230336/mLQC1D4E_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 33,
#     'favorite_count': 66,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'ja'},
#    'is_quote_status': False,
#    'retweet_count': 33,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   {'created_at': 'Fri Sep 21 03:59:06 +0000 2018',
#    'id': 1042986552832348160,
#    'id_str': '1042986552832348160',
#    'text': 'RT @usairforce: “Our dogs are definitely not pets; they are #MilitaryWorkingDogs – assets to the #USAF…The trust these teams have in each o…',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'MilitaryWorkingDogs',
#       'indices': [60, 80]},
#      {'text': 'USAF', 'indices': [97, 102]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'usairforce',
#       'name': 'U.S. Air Force',
#       'id': 19611483,
#       'id_str': '19611483',
#       'indices': [3, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 966732397936021505,
#     'id_str': '966732397936021505',
#     'name': 'jon🐻#internetbillofrights',
#     'screen_name': 'staggerlee422',
#     'location': '',
#     'description': '#MAGA #DrainTheSwamp #BuildTheWall #Qanon #TheGreatAwakening #unBearAbles Just an old pissed off American.. I need a miracle everyday..',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 4708,
#     'friends_count': 4510,
#     'listed_count': 6,
#     'created_at': 'Thu Feb 22 17:52:19 +0000 2018',
#     'favourites_count': 35029,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 33516,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1035217334934204418/Mow35FZE_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1035217334934204418/Mow35FZE_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/966732397936021505/1537324978',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Fri Sep 21 02:00:00 +0000 2018',
#     'id': 1042956581715890176,
#     'id_str': '1042956581715890176',
#     'text': '“Our dogs are definitely not pets; they are #MilitaryWorkingDogs – assets to the #USAF…The trust these teams have i… https://t.co/PVPq9Up5iN',
#     'truncated': True,
#     'entities': {'hashtags': [{'text': 'MilitaryWorkingDogs',
#        'indices': [44, 64]},
#       {'text': 'USAF', 'indices': [81, 86]}],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [{'url': 'https://t.co/PVPq9Up5iN',
#        'expanded_url': 'https://twitter.com/i/web/status/1042956581715890176',
#        'display_url': 'twitter.com/i/web/status/1…',
#        'indices': [117, 140]}]},
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'source': '<a href="https://studio.twitter.com" rel="nofollow">Media Studio</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 19611483,
#      'id_str': '19611483',
#      'name': 'U.S. Air Force',
#      'screen_name': 'usairforce',
#      'location': 'Air, Space and Cyberspace',
#      'description': 'Official U.S. Air Force Twitter (Following, RTs & links ≠ endorsement) #AirForce',
#      'url': 'http://t.co/RSyffiBLEx',
#      'entities': {'url': {'urls': [{'url': 'http://t.co/RSyffiBLEx',
#          'expanded_url': 'http://www.af.mil',
#          'display_url': 'af.mil',
#          'indices': [0, 22]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 957637,
#      'friends_count': 513,
#      'listed_count': 6317,
#      'created_at': 'Tue Jan 27 19:48:52 +0000 2009',
#      'favourites_count': 1040,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': True,
#      'statuses_count': 38276,
#      'lang': 'en',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/875377950861950976/WDv6YJ5d_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/875377950861950976/WDv6YJ5d_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19611483/1537211046',
#      'profile_link_color': '0018B3',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'EDF7FB',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 84,
#     'favorite_count': 279,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 84,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   {'created_at': 'Fri Sep 21 03:59:06 +0000 2018',
#    'id': 1042986551452426241,
#    'id_str': '1042986551452426241',
#    'text': '@OpTic_Crimsix We’ve had all female dogs my entire life without much problems. They usually get jealous of each other though',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'OpTic_Crimsix',
#       'name': 'Ian Porter',
#       'id': 231992478,
#       'id_str': '231992478',
#       'indices': [0, 14]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1042969479330910208,
#    'in_reply_to_status_id_str': '1042969479330910208',
#    'in_reply_to_user_id': 231992478,
#    'in_reply_to_user_id_str': '231992478',
#    'in_reply_to_screen_name': 'OpTic_Crimsix',
#    'user': {'id': 751805463239401473,
#     'id_str': '751805463239401473',
#     'name': 'Shane',
#     'screen_name': 'its_Shanerr',
#     'location': 'Texas, USA',
#     'description': 'Musician. Gamer. Golfer. PSN: Its_Shanerr',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 47,
#     'friends_count': 136,
#     'listed_count': 1,
#     'created_at': 'Sat Jul 09 15:49:25 +0000 2016',
#     'favourites_count': 3890,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2065,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1010162311892529152/Cf5Q1Ajf_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1010162311892529152/Cf5Q1Ajf_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/751805463239401473/1473785404',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'}],
#  'search_metadata': {'completed_in': 0.065,
#   'max_id': 1042986593626148864,
#   'max_id_str': '1042986593626148864',
#   'next_results': '?max_id=1042986551452426240&q=dogs&include_entities=1',
#   'query': 'dogs',
#   'refresh_url': '?since_id=1042986593626148864&q=dogs&include_entities=1',
#   'count': 15,
#   'since_id': 0,
#   'since_id_str': '0'}}
