# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create dummy data
from sklearn.datasets.samples_generator import make_blobs

X, _ = make_blobs(n_samples=500, centers=6,
                            cluster_std=0.70, random_state=0)

# %%
# Plot and show scatter
plt.scatter(X[:, 0], X[:, 1])

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans


# Create a kmeans model using k = 12
kmeans = KMeans(n_clusters=12)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
kmeans.fit(X)

predicted_clusters = kmeans.predict(X)

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
# Bonus
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

print(centers)
print(labels)
# Out:
# [[ 0.30218339  5.13280131]
#  [ 6.21228264  0.04853379]
#  [ 9.27772119 -2.34305358]
#  [ 1.7108632   1.20240138]
#  [-1.18124037  3.20792999]
#  [-1.8305068   7.36886176]
#  [ 1.60869102  4.42387539]
#  [-2.03934675  2.33042574]
#  [ 5.58882333  1.05152486]
#  [-1.00171539  8.14789275]
#  [ 0.48587837  3.74054873]
#  [ 2.36587997  0.27106548]]
# [ 2 11  9  1  9  4  4 10 11  7  2  9  0  4 10  6  2  2 11  4  8 10  5  1
#   9  0  5  7  2 11  1  5  0 10  3  4  2 11  3  0  8  2  3  7  2 11  1  2
#   1 11  2  3  9  3  0 11  7  7  1 11  9  8  2  3 10  3  4  3 11  7  3  4
#   0  5  4  7  2  0  2  2  1  1  2  8  4 10  0  2  4  1  6  6  5  8  7  8
#   5  5  7  2  9  5  6  3 11  4  5  2  2  8  8  7 11  6  8 11  3  1  2  2
#   4  3  9  2  4 10  4  4  6  2 11  1  1  4  3  6  2  4  8  1  8 10  7 11
#   2  2  7 11  8  9  9  8  0  0  4  2  4  4  3  6  0  2  2  7  1  5  0 11
#   3  4  3  2  9  9  3  1  9  1  2  5  8  0  5  3  9  2  8 10  2  3  3  2
#   1  9  4  9  9  7  2  2  8  8  1  3  5 10  2  2  3  9  1  7  6  1  2  0
#   2  4  2  9  3 11  6  4  5  9  8  8  6  7  9  2  5  3  8  0  2  2  4  2
#   8  2  6 11 10  9  1  3 11  8  2  4 10  1  6  4 11  6  9  0  5  2  9  9
#   5  3  6  4 11  7  4 10  6  9  7  3  2  7  9  7  8  2  5  3  3  7  6  7
#   9  7  2  2  4 11  6  6  3  8  2 10  5  2  2  0  3  7  2 10  8  7 10  1
#   8  5 11  8  6 10 10  0  5  1  2  9 10 11 10  5  2  8  3 11  8  4  4  6
#  10  7  7  5  3  2  9 10  5  8  7  4  3  2  0  4  7  3  7  0 11  3  7 10
#   6  2  7 11  2  6  5  3  7  7  9  2  3  5  1  6  3  3  8  0  2  6  8  1
#   1  6  1  2  1  2  2  1  5  5  2  2  9  8  1  8  1  3  2 11 10  7  5  3
#   7  0  4 10  5  2  8  6  8  5  3 10  1  2 10  3  8  5  2 11 11  6  7  2
#   3  6  4  8  2  3  2  4 10  2 11  9  3  8  0  6  9  3  3  6  6  5 10  7
#   8  4  5  3  1  5  2  9  8  9 10  8  9  9  9  5  5 10  2  4  2 11  6  7
#   2  1  6  1  9  8 11  8 10  5  5  2  9  2  0  8  4  5  5  8]

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.show()
