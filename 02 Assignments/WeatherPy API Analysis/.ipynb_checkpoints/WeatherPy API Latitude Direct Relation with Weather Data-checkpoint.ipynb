# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import wkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %%
# Set up a new Data Frame to hold the values
cities_df = pd.DataFrame({
    "City": cities,
    "Cloudiness": "",
    "Country": "",
    "Date": "",
    "Humidity": "",
    "Lat": "",
    "Lng": "",
    "Max Temp": "",
    "Wind Speed": ""
})

cities_df.head()
# Out:
#            City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0  kudahuvadhoo
# 1       cuiluan
# 2     mogadishu
# 3   new norfolk
# 4      montrose

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting statement as example
print("Beginning Data Retrieval")
print("-----------------------------")

# Set API key and create base url
base_url = "http://api.openweathermap.org/data/2.5/weather?"
params = {
   "Units": "Imperial",
    "APPID": wkey,
}

# Create a query url to use cities list data and generate each key items

for index, city in cities_df.iterrows():
    # Get City from df
    city_name = city["City"]
    
    # Add keyword to params dict
    params["q"] = city_name
    
    response = requests.get(base_url, params=params).json()
    
    # extract results
    #results = response["result"]
    
# Exception handling
    try:
        print(f"Processing Reocrd {index}| {city_name}.")
        #parse response
        cities_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        cities_df.loc[index, "Country"] = response["sys"]["country"]
        cities_df.loc[index, "Date"] = response["dt"]
        cities_df.loc[index, "Humidity"] = response["main"]["humidity"]
        cities_df.loc[index, "Lat"] = response["coord"]["lat"]
        cities_df.loc[index, "Lng"] = response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        cities_df.loc[index, "Wind Speed"] = response["wind"]["speed"]

    except(KeyError, ValueError):
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Reocrd 0| kudahuvadhoo.
# Processing Reocrd 1| cuiluan.
# Processing Reocrd 2| mogadishu.
# Processing Reocrd 3| new norfolk.
# Processing Reocrd 4| montrose.
# Processing Reocrd 5| clonakilty.
# Processing Reocrd 6| mahebourg.
# Processing Reocrd 7| torbay.
# Processing Reocrd 8| mys shmidta.
# City not found. Skipping...
# Processing Reocrd 9| hovd.
# Processing Reocrd 10| khatanga.
# Processing Reocrd 11| turukhansk.
# Processing Reocrd 12| chuy.
# Processing Reocrd 13| jinchengjiang.
# City not found. Skipping...
# Processing Reocrd 14| acapulco.
# Processing Reocrd 15| kapaa.
# Processing Reocrd 16| naze.
# Processing Reocrd 17| tuktoyaktuk.
# Processing Reocrd 18| ushuaia.
# Processing Reocrd 19| moerai.
# Processing Reocrd 20| punta arenas.
# Processing Reocrd 21| norman wells.
# Processing Reocrd 22| dikson.
# Processing Reocrd 23| babanusah.
# City not found. Skipping...
# Processing Reocrd 24| lebu.
# Processing Reocrd 25| royan.
# Processing Reocrd 26| port elizabeth.
# Processing Reocrd 27| nikolskoye.
# Processing Reocrd 28| east london.
# Processing Reocrd 29| lasa.
# Processing Reocrd 30| shubarshi.
# Processing Reocrd 31| klaksvik.
# Processing Reocrd 32| rikitea.
# Processing Reocrd 33| thompson.
# Processing Reocrd 34| mar del plata.
# Processing Reocrd 35| beian.
# Processing Reocrd 36| hithadhoo.
# Processing Reocrd 37| wajir.
# Processing Reocrd 38| barrow.
# Processing Reocrd 39| bambanglipuro.
# Processing Reocrd 40| saint combs.
# City not found. Skipping...
# Processing Reocrd 41| manerbio.
# Processing Reocrd 42| hermanus.
# Processing Reocrd 43| jamestown.
# Processing Reocrd 44| severo-kurilsk.
# Processing Reocrd 45| moratuwa.
# Processing Reocrd 46| ukiah.
# Processing Reocrd 47| tasiilaq.
# Processing Reocrd 48| porto novo.
# Processing Reocrd 49| sentyabrskiy.
# City not found. Skipping...
# Processing Reocrd 50| attawapiskat.
# City not found. Skipping...
# Processing Reocrd 51| gawler.
# Processing Reocrd 52| gat.
# Processing Reocrd 53| alakurtti.
# Processing Reocrd 54| albany.
# Processing Reocrd 55| lubao.
# Processing Reocrd 56| mataura.
# Processing Reocrd 57| lavrentiya.
# Processing Reocrd 58| port hardy.
# Processing Reocrd 59| san patricio.
# Processing Reocrd 60| esperance.
# Processing Reocrd 61| isangel.
# Processing Reocrd 62| ouro preto do oeste.
# Processing Reocrd 63| nizhneyansk.
# City not found. Skipping...
# Processing Reocrd 64| westport.
# Processing Reocrd 65| vikhorevka.
# Processing Reocrd 66| busselton.
# Processing Reocrd 67| te anau.
# Processing Reocrd 68| hilo.
# Processing Reocrd 69| rondonopolis.
# Processing Reocrd 70| camacha.
# Processing Reocrd 71| lolua.
# City not found. Skipping...
# Processing Reocrd 72| payson.
# Processing Reocrd 73| krasnokamensk.
# Processing Reocrd 74| beloeil.
# Processing Reocrd 75| tuatapere.
# Processing Reocrd 76| sembe.
# City not found. Skipping...
# Processing Reocrd 77| geraldton.
# Processing Reocrd 78| deputatskiy.
# Processing Reocrd 79| namibe.
# Processing Reocrd 80| bluff.
# Processing Reocrd 81| najran.
# Processing Reocrd 82| pangody.
# Processing Reocrd 83| bredasdorp.
# Processing Reocrd 84| illoqqortoormiut.
# City not found. Skipping...
# Processing Reocrd 85| ljaskovec.
# City not found. Skipping...
# Processing Reocrd 86| ponta do sol.
# Processing Reocrd 87| saint-pierre.
# Processing Reocrd 88| taolanaro.
# City not found. Skipping...
# Processing Reocrd 89| puerto ayora.
# Processing Reocrd 90| kamenka.
# Processing Reocrd 91| sibu.
# Processing Reocrd 92| hobart.
# Processing Reocrd 93| sinor.
# Processing Reocrd 94| qaanaaq.
# Processing Reocrd 95| azimur.
# City not found. Skipping...
# Processing Reocrd 96| airai.
# Processing Reocrd 97| necochea.
# Processing Reocrd 98| cape town.
# Processing Reocrd 99| troitskoye.
# Processing Reocrd 100| yellowknife.
# Processing Reocrd 101| fortuna.
# Processing Reocrd 102| ribeira grande.
# Processing Reocrd 103| belmonte.
# Processing Reocrd 104| port alfred.
# Processing Reocrd 105| maues.
# Processing Reocrd 106| meyungs.
# City not found. Skipping...
# Processing Reocrd 107| ancud.
# Processing Reocrd 108| taoudenni.
# Processing Reocrd 109| ambulu.
# Processing Reocrd 110| bognor regis.
# Processing Reocrd 111| iqaluit.
# Processing Reocrd 112| cedar city.
# Processing Reocrd 113| gidam.
# Processing Reocrd 114| kalaleh.
# Processing Reocrd 115| beringovskiy.
# Processing Reocrd 116| san fernando.
# Processing Reocrd 117| saskylakh.
# Processing Reocrd 118| victoria.
# Processing Reocrd 119| hasaki.
# Processing Reocrd 120| arsikere.
# Processing Reocrd 121| castro.
# Processing Reocrd 122| vega de alatorre.
# Processing Reocrd 123| carnarvon.
# Processing Reocrd 124| arraial do cabo.
# Processing Reocrd 125| chagda.
# City not found. Skipping...
# Processing Reocrd 126| marrakesh.
# Processing Reocrd 127| beloha.
# Processing Reocrd 128| saint-felicien.
# Processing Reocrd 129| amahai.
# Processing Reocrd 130| manokwari.
# Processing Reocrd 131| sao filipe.
# Processing Reocrd 132| yenagoa.
# Processing Reocrd 133| erice.
# Processing Reocrd 134| gizo.
# Processing Reocrd 135| mount gambier.
# Processing Reocrd 136| saldanha.
# Processing Reocrd 137| hirado.
# Processing Reocrd 138| atocha.
# Processing Reocrd 139| tamandare.
# Processing Reocrd 140| codrington.
# Processing Reocrd 141| kewanee.
# Processing Reocrd 142| xuddur.
# Processing Reocrd 143| barentsburg.
# City not found. Skipping...
# Processing Reocrd 144| kavieng.
# Processing Reocrd 145| labuhan.
# Processing Reocrd 146| itarema.
# Processing Reocrd 147| pevek.
# Processing Reocrd 148| santander jimenez.
# Processing Reocrd 149| belushya guba.
# City not found. Skipping...
# Processing Reocrd 150| touros.
# Processing Reocrd 151| atuona.
# Processing Reocrd 152| cherskiy.
# Processing Reocrd 153| provideniya.
# Processing Reocrd 154| kalemie.
# Processing Reocrd 155| portland.
# Processing Reocrd 156| butaritari.
# Processing Reocrd 157| omboue.
# Processing Reocrd 158| pak phanang.
# Processing Reocrd 159| riaba.
# City not found. Skipping...
# Processing Reocrd 160| noumea.
# Processing Reocrd 161| kingman.
# Processing Reocrd 162| upernavik.
# Processing Reocrd 163| tabialan.
# City not found. Skipping...
# Processing Reocrd 164| alcaniz.
# Processing Reocrd 165| vernon.
# Processing Reocrd 166| amderma.
# City not found. Skipping...
# Processing Reocrd 167| hay river.
# Processing Reocrd 168| roald.
# Processing Reocrd 169| praia.
# Processing Reocrd 170| mabaruma.
# Processing Reocrd 171| barawe.
# City not found. Skipping...
# Processing Reocrd 172| bahia honda.
# Processing Reocrd 173| hamptons at boca raton.
# Processing Reocrd 174| kodiak.
# Processing Reocrd 175| amsterdam.
# Processing Reocrd 176| katsuura.
# Processing Reocrd 177| saint-philippe.
# Processing Reocrd 178| lorengau.
# Processing Reocrd 179| avarua.
# Processing Reocrd 180| mahadday weyne.
# City not found. Skipping...
# Processing Reocrd 181| astoria.
# Processing Reocrd 182| laguna.
# Processing Reocrd 183| umzimvubu.
# City not found. Skipping...
# Processing Reocrd 184| san pedro.
# Processing Reocrd 185| samarai.
# Processing Reocrd 186| petropavlovsk-kamchatskiy.
# Processing Reocrd 187| suntar.
# Processing Reocrd 188| manggar.
# Processing Reocrd 189| ranau.
# Processing Reocrd 190| leningradskiy.
# Processing Reocrd 191| nemuro.
# Processing Reocrd 192| hamilton.
# Processing Reocrd 193| cidreira.
# Processing Reocrd 194| grand river south east.
# City not found. Skipping...
# Processing Reocrd 195| cabo san lucas.
# Processing Reocrd 196| ahipara.
# Processing Reocrd 197| plastun.
# Processing Reocrd 198| flinders.
# Processing Reocrd 199| tagusao.
# Processing Reocrd 200| jumla.
# Processing Reocrd 201| grootfontein.
# Processing Reocrd 202| sedro-woolley.
# Processing Reocrd 203| gorontalo.
# Processing Reocrd 204| zhoucheng.
# Processing Reocrd 205| manuel doblado.
# City not found. Skipping...
# Processing Reocrd 206| vaini.
# Processing Reocrd 207| juegang.
# Processing Reocrd 208| russell.
# Processing Reocrd 209| vaitupu.
# City not found. Skipping...
# Processing Reocrd 210| charters towers.
# Processing Reocrd 211| tsihombe.
# City not found. Skipping...
# Processing Reocrd 212| whitefish.
# Processing Reocrd 213| kihei.
# Processing Reocrd 214| sao joao da barra.
# Processing Reocrd 215| moree.
# Processing Reocrd 216| makakilo city.
# Processing Reocrd 217| collie.
# Processing Reocrd 218| benxi.
# Processing Reocrd 219| dudinka.
# Processing Reocrd 220| ballina.
# Processing Reocrd 221| bethel.
# Processing Reocrd 222| port blair.
# Processing Reocrd 223| gangotri.
# City not found. Skipping...
# Processing Reocrd 224| biak.
# Processing Reocrd 225| vittoria.
# Processing Reocrd 226| hlatikulu.
# Processing Reocrd 227| maumere.
# Processing Reocrd 228| elliot.
# Processing Reocrd 229| genhe.
# Processing Reocrd 230| sohag.
# Processing Reocrd 231| balikpapan.
# Processing Reocrd 232| souillac.
# Processing Reocrd 233| jicin.
# Processing Reocrd 234| namatanai.
# Processing Reocrd 235| caravelas.
# Processing Reocrd 236| lujan.
# Processing Reocrd 237| baltoji voke.
# Processing Reocrd 238| ostrovnoy.
# Processing Reocrd 239| myre.
# Processing Reocrd 240| opobo.
# City not found. Skipping...
# Processing Reocrd 241| mahibadhoo.
# Processing Reocrd 242| husavik.
# Processing Reocrd 243| saint george.
# Processing Reocrd 244| bardiyah.
# City not found. Skipping...
# Processing Reocrd 245| huambo.
# Processing Reocrd 246| borovoy.
# Processing Reocrd 247| lalmohan.
# Processing Reocrd 248| arlit.
# Processing Reocrd 249| adrar.
# Processing Reocrd 250| vestmannaeyjar.
# Processing Reocrd 251| chokurdakh.
# Processing Reocrd 252| soe.
# Processing Reocrd 253| guerrero negro.
# Processing Reocrd 254| salinopolis.
# Processing Reocrd 255| caronport.
# Processing Reocrd 256| shache.
# Processing Reocrd 257| karratha.
# Processing Reocrd 258| luderitz.
# Processing Reocrd 259| guna.
# Processing Reocrd 260| malanje.
# Processing Reocrd 261| kabompo.
# Processing Reocrd 262| vila velha.
# Processing Reocrd 263| dehloran.
# Processing Reocrd 264| salina cruz.
# Processing Reocrd 265| hendijan.
# City not found. Skipping...
# Processing Reocrd 266| acajutla.
# Processing Reocrd 267| haines junction.
# Processing Reocrd 268| padang.
# Processing Reocrd 269| kaitangata.
# Processing Reocrd 270| gao.
# Processing Reocrd 271| atar.
# Processing Reocrd 272| yanan.
# City not found. Skipping...
# Processing Reocrd 273| vardo.
# Processing Reocrd 274| xining.
# Processing Reocrd 275| erode.
# Processing Reocrd 276| fayaoue.
# Processing Reocrd 277| panaba.
# Processing Reocrd 278| ilulissat.
# Processing Reocrd 279| stornoway.
# City not found. Skipping...
# Processing Reocrd 280| fairbanks.
# Processing Reocrd 281| waingapu.
# Processing Reocrd 282| ambon.
# Processing Reocrd 283| lagoa.
# Processing Reocrd 284| olive branch.
# Processing Reocrd 285| hudson bay.
# Processing Reocrd 286| alofi.
# Processing Reocrd 287| rawson.
# Processing Reocrd 288| lillooet.
# Processing Reocrd 289| samusu.
# City not found. Skipping...
# Processing Reocrd 290| kingsburg.
# Processing Reocrd 291| dunedin.
# Processing Reocrd 292| faanui.
# Processing Reocrd 293| clyde river.
# Processing Reocrd 294| parauna.
# Processing Reocrd 295| vostok.
# Processing Reocrd 296| sterling.
# Processing Reocrd 297| bur gabo.
# City not found. Skipping...
# Processing Reocrd 298| tumannyy.
# City not found. Skipping...
# Processing Reocrd 299| bubaque.
# Processing Reocrd 300| kungurtug.
# Processing Reocrd 301| ixtapa.
# Processing Reocrd 302| ende.
# Processing Reocrd 303| takoradi.
# Processing Reocrd 304| korla.
# City not found. Skipping...
# Processing Reocrd 305| kahului.
# Processing Reocrd 306| port moresby.
# Processing Reocrd 307| san juan.
# Processing Reocrd 308| maputo.
# Processing Reocrd 309| mwanza.
# Processing Reocrd 310| nouadhibou.
# Processing Reocrd 311| vestmanna.
# Processing Reocrd 312| port lincoln.
# Processing Reocrd 313| rioja.
# Processing Reocrd 314| rulenge.
# Processing Reocrd 315| el alto.
# Processing Reocrd 316| havre-saint-pierre.
# Processing Reocrd 317| formoso do araguaia.
# City not found. Skipping...
# Processing Reocrd 318| mizdah.
# Processing Reocrd 319| carutapera.
# Processing Reocrd 320| barbar.
# City not found. Skipping...
# Processing Reocrd 321| sovetskiy.
# Processing Reocrd 322| marivan.
# Processing Reocrd 323| boulder.
# Processing Reocrd 324| nynashamn.
# Processing Reocrd 325| kununurra.
# Processing Reocrd 326| pisco.
# Processing Reocrd 327| zalha.
# Processing Reocrd 328| malwan.
# City not found. Skipping...
# Processing Reocrd 329| lira.
# Processing Reocrd 330| yashkul.
# Processing Reocrd 331| gaoua.
# Processing Reocrd 332| kazalinsk.
# City not found. Skipping...
# Processing Reocrd 333| anadyr.
# Processing Reocrd 334| ust-bolsheretsk.
# City not found. Skipping...
# Processing Reocrd 335| itoman.
# Processing Reocrd 336| palmares do sul.
# Processing Reocrd 337| olinda.
# Processing Reocrd 338| medowie.
# Processing Reocrd 339| nhamunda.
# Processing Reocrd 340| coquimbo.
# Processing Reocrd 341| damme.
# Processing Reocrd 342| hualmay.
# Processing Reocrd 343| vasterhaninge.
# Processing Reocrd 344| vrangel.
# Processing Reocrd 345| det udom.
# Processing Reocrd 346| agadir.
# Processing Reocrd 347| tautira.
# Processing Reocrd 348| velyka bilozerka.
# Processing Reocrd 349| grindavik.
# Processing Reocrd 350| shingu.
# Processing Reocrd 351| saint-augustin.
# Processing Reocrd 352| kragero.
# Processing Reocrd 353| eureka.
# Processing Reocrd 354| lomovka.
# Processing Reocrd 355| viligili.
# City not found. Skipping...
# Processing Reocrd 356| paragominas.
# Processing Reocrd 357| gander.
# Processing Reocrd 358| ovsyanka.
# Processing Reocrd 359| markala.
# Processing Reocrd 360| mawlaik.
# Processing Reocrd 361| wagar.
# Processing Reocrd 362| isahaya.
# Processing Reocrd 363| deh rawud.
# City not found. Skipping...
# Processing Reocrd 364| port augusta.
# Processing Reocrd 365| santa maria.
# Processing Reocrd 366| farafangana.
# Processing Reocrd 367| georgetown.
# Processing Reocrd 368| mehamn.
# Processing Reocrd 369| harper.
# Processing Reocrd 370| vila franca do campo.
# Processing Reocrd 371| oksfjord.
# Processing Reocrd 372| poum.
# Processing Reocrd 373| aykhal.
# Processing Reocrd 374| zachary.
# Processing Reocrd 375| dukuhturi.
# Processing Reocrd 376| gohpur.
# Processing Reocrd 377| pudozh.
# Processing Reocrd 378| ihosy.
# Processing Reocrd 379| evensk.
# Processing Reocrd 380| muisne.
# Processing Reocrd 381| bambous virieux.
# Processing Reocrd 382| barao de melgaco.
# Processing Reocrd 383| zafra.
# Processing Reocrd 384| lebedyn.
# Processing Reocrd 385| axim.
# Processing Reocrd 386| pochutla.
# Processing Reocrd 387| krasnoselkup.
# City not found. Skipping...
# Processing Reocrd 388| gurupa.
# City not found. Skipping...
# Processing Reocrd 389| malinovoye ozero.
# Processing Reocrd 390| kalevala.
# Processing Reocrd 391| marcona.
# City not found. Skipping...
# Processing Reocrd 392| swan hill.
# Processing Reocrd 393| ust-kamchatsk.
# City not found. Skipping...
# Processing Reocrd 394| pachino.
# Processing Reocrd 395| san jose.
# Processing Reocrd 396| talcahuano.
# Processing Reocrd 397| seoul.
# Processing Reocrd 398| doctor arroyo.
# Processing Reocrd 399| tiksi.
# Processing Reocrd 400| maniitsoq.
# Processing Reocrd 401| bathsheba.
# Processing Reocrd 402| nguiu.
# City not found. Skipping...
# Processing Reocrd 403| negotin.
# Processing Reocrd 404| port hedland.
# Processing Reocrd 405| lahad datu.
# Processing Reocrd 406| kodinsk.
# Processing Reocrd 407| matara.
# Processing Reocrd 408| bengkulu.
# City not found. Skipping...
# Processing Reocrd 409| blagoyevo.
# Processing Reocrd 410| mehran.
# Processing Reocrd 411| bima.
# Processing Reocrd 412| kruisfontein.
# Processing Reocrd 413| eidsvag.
# Processing Reocrd 414| synya.
# Processing Reocrd 415| komsomolskiy.
# Processing Reocrd 416| hammerfest.
# Processing Reocrd 417| tabuk.
# Processing Reocrd 418| yerbogachen.
# Processing Reocrd 419| cockburn harbour.
# City not found. Skipping...
# Processing Reocrd 420| milcovul.
# Processing Reocrd 421| kaduna.
# Processing Reocrd 422| sharon.
# Processing Reocrd 423| preston.
# Processing Reocrd 424| kloulklubed.
# Processing Reocrd 425| aktau.
# Processing Reocrd 426| topolovgrad.
# Processing Reocrd 427| rancharia.
# Processing Reocrd 428| flin flon.
# Processing Reocrd 429| longyearbyen.
# Processing Reocrd 430| svetlogorsk.
# Processing Reocrd 431| yar-sale.
# Processing Reocrd 432| zhigansk.
# Processing Reocrd 433| weinan.
# Processing Reocrd 434| veraval.
# Processing Reocrd 435| visnes.
# Processing Reocrd 436| barinas.
# Processing Reocrd 437| commerce.
# Processing Reocrd 438| mutare.
# Processing Reocrd 439| villa maria.
# Processing Reocrd 440| tigbao.
# Processing Reocrd 441| stokmarknes.
# Processing Reocrd 442| narsaq.
# Processing Reocrd 443| marang.
# City not found. Skipping...
# Processing Reocrd 444| tyrma.
# Processing Reocrd 445| leh.
# Processing Reocrd 446| inhumas.
# Processing Reocrd 447| canutama.
# Processing Reocrd 448| sitka.
# Processing Reocrd 449| lerwick.
# Processing Reocrd 450| berlevag.
# Processing Reocrd 451| tessalit.
# Processing Reocrd 452| ternate.
# Processing Reocrd 453| parabel.
# Processing Reocrd 454| alta floresta.
# Processing Reocrd 455| ossora.
# Processing Reocrd 456| lichtenburg.
# Processing Reocrd 457| barreirinhas.
# Processing Reocrd 458| ornskoldsvik.
# Processing Reocrd 459| faya.
# Processing Reocrd 460| yulara.
# Processing Reocrd 461| atikokan.
# Processing Reocrd 462| wajima.
# Processing Reocrd 463| safaga.
# City not found. Skipping...
# Processing Reocrd 464| auki.
# Processing Reocrd 465| hobyo.
# Processing Reocrd 466| nanortalik.
# Processing Reocrd 467| gobabis.
# Processing Reocrd 468| ketchikan.
# Processing Reocrd 469| sibiti.
# Processing Reocrd 470| kupang.
# Processing Reocrd 471| kalmunai.
# Processing Reocrd 472| ondangwa.
# Processing Reocrd 473| kharp.
# Processing Reocrd 474| shenavan.
# Processing Reocrd 475| zhanaozen.
# Processing Reocrd 476| rungata.
# City not found. Skipping...
# Processing Reocrd 477| darnah.
# Processing Reocrd 478| san pedro de macoris.
# Processing Reocrd 479| salalah.
# Processing Reocrd 480| halifax.
# Processing Reocrd 481| majene.
# Processing Reocrd 482| kashi.
# City not found. Skipping...
# Processing Reocrd 483| okhotsk.
# Processing Reocrd 484| nara.
# Processing Reocrd 485| nakusp.
# Processing Reocrd 486| andros town.
# Processing Reocrd 487| waddan.
# Processing Reocrd 488| kailua.
# Processing Reocrd 489| inhambane.
# Processing Reocrd 490| salinas.
# Processing Reocrd 491| kassala.
# Processing Reocrd 492| murgab.
# Processing Reocrd 493| villeneuve-loubet.
# Processing Reocrd 494| asnaes.
# Processing Reocrd 495| lakatoro.
# Processing Reocrd 496| zhezkazgan.
# Processing Reocrd 497| ola.
# Processing Reocrd 498| nome.
# Processing Reocrd 499| balakhta.
# Processing Reocrd 500| umm lajj.
# Processing Reocrd 501| dwarka.
# Processing Reocrd 502| maceio.
# Processing Reocrd 503| nantucket.
# Processing Reocrd 504| porbandar.
# Processing Reocrd 505| taltal.
# Processing Reocrd 506| sironj.
# Processing Reocrd 507| srednekolymsk.
# Processing Reocrd 508| eenhana.
# Processing Reocrd 509| stykkisholmur.
# Processing Reocrd 510| sibolga.
# Processing Reocrd 511| kiunga.
# Processing Reocrd 512| wakkanai.
# Processing Reocrd 513| predivinsk.
# Processing Reocrd 514| maracaibo.
# Processing Reocrd 515| talnakh.
# Processing Reocrd 516| varna.
# Processing Reocrd 517| nata.
# Processing Reocrd 518| sangar.
# Processing Reocrd 519| qixingtai.
# Processing Reocrd 520| puerto colombia.
# Processing Reocrd 521| blagoveshchensk.
# Processing Reocrd 522| lethem.
# Processing Reocrd 523| swellendam.
# Processing Reocrd 524| tateyama.
# Processing Reocrd 525| xai-xai.
# Processing Reocrd 526| manta.
# Processing Reocrd 527| gambela.
# Processing Reocrd 528| ambilobe.
# Processing Reocrd 529| fukue.
# Processing Reocrd 530| katherine.
# Processing Reocrd 531| caraguatatuba.
# Processing Reocrd 532| vagamo.
# Processing Reocrd 533| port-gentil.
# Processing Reocrd 534| boralday.
# Processing Reocrd 535| itupiranga.
# Processing Reocrd 536| san quintin.
# Processing Reocrd 537| morondava.
# Processing Reocrd 538| balatonfoldvar.
# Processing Reocrd 539| myitkyina.
# Processing Reocrd 540| henties bay.
# Processing Reocrd 541| alta.
# Processing Reocrd 542| saint anthony.
# Processing Reocrd 543| camacupa.
# Processing Reocrd 544| egvekinot.
# Processing Reocrd 545| celestun.
# Processing Reocrd 546| araouane.
# Processing Reocrd 547| kabo.
# Processing Reocrd 548| sanchazi.
# Processing Reocrd 549| maryville.
# Processing Reocrd 550| viedma.
# Processing Reocrd 551| nuuk.
# Processing Reocrd 552| gravdal.
# Processing Reocrd 553| shakawe.
# Processing Reocrd 554| skelleftea.
# Processing Reocrd 555| hervey bay.
# Processing Reocrd 556| santa marta.
# Processing Reocrd 557| ulladulla.
# Processing Reocrd 558| fort nelson.
# Processing Reocrd 559| marawi.
# Processing Reocrd 560| shiroishi.
# Processing Reocrd 561| waterloo.
# Processing Reocrd 562| kargopol.
# Processing Reocrd 563| lata.
# Processing Reocrd 564| isiro.
# Processing Reocrd 565| yokadouma.
# Processing Reocrd 566| macau.
# Processing Reocrd 567| gaya.
# Processing Reocrd 568| sandy bay.
# Processing Reocrd 569| jurado.
# City not found. Skipping...
# Processing Reocrd 570| los llanos de aridane.
# Processing Reocrd 571| muroto.
# Processing Reocrd 572| aksarka.
# Processing Reocrd 573| linguere.
# City not found. Skipping...
# Processing Reocrd 574| cieszyn.
# Processing Reocrd 575| middlebury.
# Processing Reocrd 576| tinde.
# Processing Reocrd 577| mao.
# Processing Reocrd 578| himora.
# City not found. Skipping...
# Processing Reocrd 579| pinahat.
# Processing Reocrd 580| yirol.
# City not found. Skipping...
# Processing Reocrd 581| guadalupe y calvo.
# Processing Reocrd 582| hami.
# Processing Reocrd 583| oxford.
# Processing Reocrd 584| barra do garcas.
# Processing Reocrd 585| roros.
# Processing Reocrd 586| bud.
# Processing Reocrd 587| astana.
# Processing Reocrd 588| kamenskoye.
# City not found. Skipping...
# Processing Reocrd 589| tual.
# Processing Reocrd 590| imeni poliny osipenko.
# Processing Reocrd 591| neryungri.
# Processing Reocrd 592| onega.
# Processing Reocrd 593| barillas.
# Processing Reocrd 594| athabasca.
# Processing Reocrd 595| yumen.
# Processing Reocrd 596| pindobacu.
# Processing Reocrd 597| tomakomai.
# Processing Reocrd 598| inuvik.
# Processing Reocrd 599| methven.
# Processing Reocrd 600| southbridge.
# Processing Reocrd 601| groningen.
# Processing Reocrd 602| ikom.
# Processing Reocrd 603| tsienyane.
# City not found. Skipping...
# Processing Reocrd 604| oranjestad.
# Processing Reocrd 605| ucluelet.
# Processing Reocrd 606| caraballeda.
# Processing Reocrd 607| ferme-neuve.
# Processing Reocrd 608| algiers.
# Processing Reocrd 609| alekseyevsk.
# Processing Reocrd 610| abu samrah.
# Processing Reocrd 611| timra.

# %%
cities_df.replace("", np.nan, inplace=True)
cities_df = cities_df.dropna(how="any")

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Create dataframe with city_data
cities_df.head()
# Out:
#            City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0  kudahuvadhoo        56.0      MV  1.536354e+09     100.0   2.67   72.89
# 1       cuiluan        92.0      CN  1.536354e+09      99.0  47.72  128.65
# 2     mogadishu        88.0      SO  1.536354e+09      99.0   2.04   45.34
# 3   new norfolk        20.0      AU  1.536352e+09      80.0 -42.78  147.06
# 4      montrose         0.0      AU  1.536352e+09      86.0 -37.81  145.34
#
#    Max Temp  Wind Speed
# 0   301.081        6.45
# 1   280.331        2.10
# 2   298.481        7.60
# 3   277.150        3.60
# 4   277.150        5.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Latitude vs Temp
plt.scatter(cities_df["Lat"], cities_df["Max Temp"], color="r", edgecolor="k")
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.xlabel("Max Temperature (F)")
plt.ylabel("Latitude")
plt.grid()


plt.savefig("Images/City Latitude vs. Max Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Latitude vs humidity
plt.scatter(cities_df["Lat"], cities_df["Humidity"], color="g", edgecolor="k")
plt.title("City Latitude vs. Humidity (08/22/18)")
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")
plt.grid()

plt.savefig("Images/City Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude vs cloudiness
plt.scatter(cities_df["Lat"], cities_df["Cloudiness"], color="b", edgecolor="k")
plt.title("City Latitude vs. Cloudiness (08/22/18)")
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")
plt.grid()

plt.savefig("Images/City Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs wind speed
plt.scatter(cities_df["Lat"], cities_df["Wind Speed"], color="y", edgecolor="k")
plt.title("City Latitude vs. Wind Speed (08/22/18)")
plt.xlabel("Wind Speed (mph)")
plt.ylabel("Latitude")
plt.grid()

plt.savefig("Images/City Latitude vs. Wind Speed.png")
plt.show()
